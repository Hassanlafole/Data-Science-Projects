# %% [markdown]
# ## Importing Lbraries

# %%
import pandas as pd
import numpy as np
import plotly.express as pe
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# hadii scikit-learn uusan kuugu jirin faldan sidaan hoos ku xusan isticmaal
# !pip install scikit-learn

# %% [markdown]
# ### Reading data and ensuring dataset variables

# %%
df=pd.read_csv("advertising.csv")

# %%
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %% [markdown]
# ## Trendline analysis for Sales as target and Radio as predictor

# %%
fig=pe.scatter(data_frame=df,x="Sales",y="Radio",size="Radio",trendline="ols")
fig.show()
# Out:
# <div>                            <div id="6159fe52-7080-4e4d-86a3-423d856f8342" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6159fe52-7080-4e4d-86a3-423d856f8342")) {                    Plotly.newPlot(                        "6159fe52-7080-4e4d-86a3-423d856f8342",                        [{"hovertemplate":"Sales=%{x}\u003cbr\u003eRadio=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","size":[37.8,39.3,45.9,41.3,10.8,48.9,32.8,19.6,2.1,2.6,5.8,24.0,35.1,7.6,32.9,47.7,36.6,39.6,20.5,23.9,27.7,5.1,15.9,16.9,12.6,3.5,29.3,16.7,27.1,16.0,28.3,17.4,1.5,20.0,1.4,4.1,43.8,49.4,26.7,37.7,22.3,33.4,27.7,8.4,25.7,22.5,9.9,41.5,15.8,11.7,3.1,9.6,41.7,46.2,28.8,49.4,28.1,19.2,49.6,29.5,2.0,42.7,15.5,29.6,42.8
# ...

# %% [markdown]
# ## Get x and y variables

# %%
features=["TV","Radio","Newspaper"]
x=df[features]
y=df["Sales"]

# %% [markdown]
# ## sptilling data into trainset and testset

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3)

# %%
ml=LinearRegression()
ml.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %% [markdown]
# ## Model Evaulation

# %%
print("Accuracy: ",ml.score(xtest,ytest))
# Out:
# Accuracy:  0.8872147465128106

# %%
adv=[[47,89,106]]
print(ml.predict(adv))
# Out:
# [17.15367285]
